# %%
import pandas as pd

# for drawing map
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
geo = pd.read_csv("DataSet/olist_geolocation_dataset.csv")

# Display the first few rows
geo.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %% [markdown]
# Brazil use 8 digit zip_code system. But, here 1 digit for major postal region, and 2-5 digit for sub_region, sector, sub_sector. But, upon checking the first few rows, I see only four digit in zip_code column. I check to see the distribution of length of zip_code in dataset.

# %%
geo["zip_code_length"] = geo["geolocation_zip_code_prefix"].astype(str).str.len()
geo["zip_code_length"].value_counts()
# Out:
# zip_code_length
# 5    754430
# 4    245733
# Name: count, dtype: int64

# %%
# Load the Stack Overflow survey data
customers = pd.read_csv("DataSet/olist_customers_dataset.csv")

# Display the first few rows
customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
cust_city = customers.groupby('customer_city')['customer_unique_id'].nunique().reset_index()
cust_city.columns = ['city', 'unique_customer_count']

# %% [markdown]
# https://www.kaggle.com/datasets/thiagobodruk/brazil-geojson

# %% [markdown]
# ### Checking Data Integrity

# %% [markdown]
# checking if `customer_state` column from **customers**, and `id` column from **geometry** is ready for join operations

# %%
customer_state =  customers[['customer_state']].drop_duplicates()
customer_state.set_index('customer_state', inplace = True)
customer_state
customer_state['label'] = 'cs'
customer_state
# Out:
#                label
# customer_state
# SP                cs
# SC                cs
# MG                cs
# PR                cs
# RJ                cs
# RS                cs
# PA                cs
# GO                cs
# ES                cs
# BA                cs
# MA                cs
# MS                cs
# CE                cs
# DF                cs
# RN                cs
# PE                cs
# MT                cs
# AM                cs
# AP                cs
# AL                cs
# RO                cs
# PB                cs
# TO                cs
# PI                cs
# AC                cs
# SE                cs
# RR                cs

# %%
geometry = gpd.read_file("DataSet/brazil_geo.json")

# %%
geometry.columns
# Out:
# Index(['id', 'name', 'geometry'], dtype='object')

# %%
geometry_state =  geometry[['id']].copy()
geometry_state.set_index('id', inplace = True)
geometry_state['label'] = 'gs'
geometry_state
# Out:
#    label
# id
# AC    gs
# AL    gs
# AP    gs
# AM    gs
# BA    gs
# CE    gs
# DF    gs
# ES    gs
# GO    gs
# MA    gs
# MT    gs
# MS    gs
# MG    gs
# PA    gs
# PB    gs
# PR    gs
# PE    gs
# PI    gs
# RJ    gs
# RN    gs
# RS    gs
# RO    gs
# RR    gs
# SC    gs
# SP    gs
# SE    gs
# TO    gs

# %%
df_concat = pd.concat([customer_state, geometry_state], axis=1)
df_concat
# Out:
#    label label
# SP    cs    gs
# SC    cs    gs
# MG    cs    gs
# PR    cs    gs
# RJ    cs    gs
# RS    cs    gs
# PA    cs    gs
# GO    cs    gs
# ES    cs    gs
# BA    cs    gs
# MA    cs    gs
# MS    cs    gs
# CE    cs    gs
# DF    cs    gs
# RN    cs    gs
# PE    cs    gs
# MT    cs    gs
# AM    cs    gs
# AP    cs    gs
# AL    cs    gs
# RO    cs    gs
# PB    cs    gs
# TO    cs    gs
# PI    cs    gs
# AC    cs    gs
# SE    cs    gs
# RR    cs    gs

# %% [markdown]
# ### Sellers Dataset

# %%
sellers = pd.read_csv("DataSet/olist_sellers_dataset.csv")
sellers.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
sellers.shape
# Out:
# (3095, 4)

# %% [markdown]
# ### Geolocation Dataset

# %%
geo.dtypes
# Out:
# geolocation_zip_code_prefix      int64
# geolocation_lat                float64
# geolocation_lng                float64
# geolocation_city                object
# geolocation_state               object
# zip_code_length                  int64
# dtype: object

# %%
geo.shape
# Out:
# (1000163, 6)

# %%
df = geo[['geolocation_zip_code_prefix']].drop_duplicates()
df.shape
# Out:
# (19015, 1)

# %%
geo.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state  zip_code_length
# 0        sao paulo                SP                4
# 1        sao paulo                SP                4
# 2        sao paulo                SP                4
# 3        sao paulo                SP                4
# 4        sao paulo                SP                4

# %%
geo[['geolocation_zip_code_prefix']].value_counts()
# Out:
# geolocation_zip_code_prefix
# 24220                          1146
# 24230                          1102
# 38400                           965
# 35500                           907
# 11680                           879
#                                ...
# 20056                             1
# 76370                             1
# 63012                             1
# 76372                             1
# 32635                             1
# Name: count, Length: 19015, dtype: int64

# %% [markdown]
# ### Assumption 1
# I found some zip_code prefix have a list of (lat, lng).
# I am checking if I could create geojson file from that.

# %%
zip_code_24220 = geo[(geo['geolocation_zip_code_prefix'] == 24220)]
zip_code_24220.head()
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 470805                        24220       -22.905817       -43.106989
# 470811                        24220       -22.902306       -43.112545
# 470812                        24220       -22.904567       -43.110491
# 470820                        24220       -22.902575       -43.109192
# 470821                        24220       -22.907500       -43.106170
#
#        geolocation_city geolocation_state  zip_code_length
# 470805          niteroi                RJ                5
# 470811          niteroi                RJ                5
# 470812          niteroi                RJ                5
# 470820          niteroi                RJ                5
# 470821          niteroi                RJ                5

# %%
import json

# Convert to [Lon, Lat] format required by GeoJSON
geojson_coords = []
for row in zip_code_24220.iterrows():
    row_values = row[1] 
    location = [row_values['geolocation_lng'], row_values['geolocation_lat']]
    geojson_coords.append(location)

# Create the structure
geojson = {
    "type": "FeatureCollection",
    "features": [
        {
            "type": "Feature",
            "id": 24220,
            "geometry": {
                "type": "LineString", # Use "Polygon" if it closes a loop
                "coordinates": geojson_coords
            },
            "properties": {}
        }
    ]
}

# Open 'data.json' in write mode and dump the data
try:
    with open("zip_code_24220.json", "w") as json_file:
        json.dump(geojson, json_file, indent=4)
    print("Successfully wrote data to data.json")
except IOError as e:
    print(f"Error writing to file: {e}")
# Out:
# Successfully wrote data to data.json

# %%
zip_code_24220_geo = gpd.read_file("zip_code_24220.json")
zip_code_24220_geo.head()
# zip_code_24220_geo.plot(edgecolor = "gray")
# Out:
#                                             geometry
# 0  LINESTRING (-22.90582 -43.10699, -22.90231 -43...

# %%
zip_code_24220_geo.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Finding 1
# I can't create gejson file from geolocation dataset.
# I will need to **remove duplicate** rows.

# %%
#convert sellers_geo to GeoDataFrame

# Create a geometry column from lat and lng
sellers_geo['geometry'] = gpd.points_from_xy(sellers_geo['lng'] ,sellers_geo['lat'] )

# Build a GeoDataFrame
sellers_geo = gpd.GeoDataFrame(sellers_geo, crs = 'epsg: 4236', geometry = sellers_geo.geometry)
sellers_geo.head()

# %%
# Spatial join of permits_geo and council_districts
permits_by_district = gpd.sjoin(permits_geo, council_districts,  predicate = "within")
print(permits_by_district.head(2))

# Create permit_counts
permit_counts = permits_by_district.groupby(['district']).size()
print(permit_counts)
